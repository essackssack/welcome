# %%
(' <h1>Dairy Management System</h1>')
# Out:
# ' <h1>Dairy Management System</h1>'

# %%
HTML('<p> welcome our page </p>')
# Out:
# <p> welcome our page </p>

# %%
print("<p> welcome our page </p>")
# Out:
# <p> welcome our page </p>

# %%
<p></p>
# Out:
#   Cell In[5], line 1
#     <p></p>
#     ^
# SyntaxError: invalid syntax

# %%
from IPython.display import HTML

# %%
<p>html</p>
# Out:
#   Cell In[7], line 1
#     <p>html</p>
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ("<h2>Hello</h2>")

# %% [markdown]
# <h1>hello </h1>

# %%
<p> hi<p>
# Out:
#   Cell In[16], line 1
#     <p> hi<p>
#     ^
# SyntaxError: invalid syntax
